# %%
def binary_search(arr, target):
    low = 0
    high = len(arr) - 1

    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)

    return merge(left_half, right_half)


def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])

    return result

    return -1

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1

        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1

        arr[j + 1] = key

    return arr

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_end_of_word = False

def add_word_to_trie(root, word):
    node = root
    for char in word:
        if char not in node.children:
            node.children[char] = TrieNode()
        node = node.children[char]
    node.is_end_of_word = True

def get_sorted_words_from_trie(root, prefix):
    result = []
    node = root
    for char in prefix:
        if char not in node.children:
            return result
        node = node.children[char]
    
    get_words_from_subtrie(node, prefix, result)
    return result

def get_words_from_subtrie(node, prefix, result):
    if node.is_end_of_word:
        result.append(prefix)
    
    for char, child in node.children.items():
        get_words_from_subtrie(child, prefix + char, result)

def sort_list_of_strings(strings):
    root = TrieNode()
    for string in strings:
        add_word_to_trie(root, string)

    return get_sorted_words_from_trie(root, "")
